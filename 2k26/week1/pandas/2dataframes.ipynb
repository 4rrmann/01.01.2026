# %%
import numpy as np
import pandas as pd

# %%
#dictionary:
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#list:
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2_nocolumnsinfo = pd.DataFrame(data_list)
df2_nocolumnsinfo
# Out:
#        0   1         2      3
# 0   John  28  New York  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
#adding column info in list:
columns = ["Name","Age","City","Salary"]
df2 = pd.DataFrame(data_list, columns=columns)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# ***selecting and indexing of Columns***

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#single target
df['Name']
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: object

# %%
#multi target
df[['Name', 'City']]
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %% [markdown]
# ***creating a new column***

# %%
df['Designation'] = ['doctor', 'engg', 'jobless', 'engg']

# %%
df
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      doctor
# 1   Anna   34     Paris   70000        engg
# 2  Peter   29    Berlin   62000     jobless
# 3  Linda   42    London   85000        engg

# %% [markdown]
# ***removing a column***

# %%
#copy of real df
df.drop('Designation', axis=1) #axis=1 {for columns}
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df #remains same
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      doctor
# 1   Anna   34     Paris   70000        engg
# 2  Peter   29    Berlin   62000     jobless
# 3  Linda   42    London   85000        engg

# %%
#now, on real data
df.drop('Designation', axis=1, inplace=True)

# %%
df #changes occur
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#multiple drops:
df.drop(["Age",'Salary'], axis=1)
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %% [markdown]
# ***removing rows***

# %%
#single drop:
df.drop(2,axis=0)
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 3  Linda   42    London   85000

# %%
#multiple drop:
df.drop([0,1],axis=0)
# Out:
#     Name  Age    City  Salary
# 2  Peter   29  Berlin   62000
# 3  Linda   42  London   85000

# %% [markdown]
# ***selecting rows***

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#single selection:
df.loc[0]
# Out:
# Name          John
# Age             28
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %%
#index locating:
df.iloc[0]
# Out:
# Name          John
# Age             28
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %%
#multiple selection:
df.loc[[0,3]]
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 3  Linda   42    London   85000

# %% [markdown]
# ***selecting subsets of rows & columns***

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df.loc[[0,1]][['City','Salary']]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
df[['Name','Age']].loc[[2,3]]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# ***Conditional selection***

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#people whose age is above 30
df[df['Age'] > 30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   Paris   70000
# 3  Linda   42  London   85000

# %%
#people whose age is above 30 & their city must be paris
df[(df['Age']>30) & (df['City']=='Paris')]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
