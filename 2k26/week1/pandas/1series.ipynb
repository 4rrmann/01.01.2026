# %% [markdown]
# ***in the world of data sci, mastering Pandas is like learning to read before writting poetry***

# %% [markdown]
# ### ***Pandas Series***

# %% [markdown]
# *A Series is a 1D labeled array capable of holding any data type. The axis labels are collectively called the index.*

# %% [markdown]
# ***Creating Series***

# %% [markdown]
# *There are multiple ways to create a pandas Series:*

# %%
import pandas as pd
import numpy as np

# %%
labels = ['a', 'b', 'c']
my_list =
