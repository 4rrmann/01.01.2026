# %% [markdown]
# ***Monolithic Systems***
# <br>*(frontend + backend + logic tightly coupled)*
# <br>        ↓
# <br>***Need for flexibility & scalability***
# <br>        ↓
# <br>***API-based Architecture***
# <br>*(client → API → backend → database)*
# <br>        ↓
# <br>***Prior backend exposure (Flask)***
# <br>*(sync, simple, limited at scale)*
# <br>        ↓
# <br>***FastAPI***
# <br>*(async, concurrent, type-safe, faster dev)*
# <br>        ↓
# <br>***Core Web Concepts***
# <br>• *HTTP methods (GET / POST / PUT / DELETE)*
# <br>• *Path & Query parameters*
# <br>• *Request / Response lifecycle*
# <br>        ↓
# <br>***Data Validation Layer***
# <br>***(Pydantic)***
# <br>• Base models
# <br>• Field & model validators
# <br>• Computed fields
# <br>• Nested schemas
# <br>• Serialization
# <br>        ↓
# <br>***Application Design***
# <br>• *Separation of concerns*
# <br>• *Versioning*
# <br>• *Error handling*
# <br>• *Response models*
# <br>        ↓
# <br>***End-to-End ML API***
# <br>*(model loading → inference → structured response)*
# <br>        ↓
# <br>***Containerization (Docker)***
# <br>• *Dockerfile → Image → Container*
# <br>• *Push to registry*
# <br>        ↓
# <br>***Cloud Deployment (AWS)***
# <br>• *Public, reproducible, scalable service*
